# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")

#  Import and read the charity_data.csv.
import pandas as pd
df_application = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
df_application.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df_applications = df_application.drop(columns = ["EIN", "NAME"])
df_applications.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
df_applications.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
count_apps =df_applications.APPLICATION_TYPE.value_counts()
count_apps
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(count_apps[count_apps < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    df_applications['APPLICATION_TYPE'] = df_applications['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df_applications['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
count_class =df_applications.CLASSIFICATION.value_counts()
count_class
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
#view classification counts > 1
count_class_gtone = count_class.loc[count_class > 1]
count_class_gtone
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(count_class[count_class < 800])
# Replace in dataframe
for cls in classifications_to_replace:
    df_applications['CLASSIFICATION'] = df_applications['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
df_applications['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_app_num = pd.get_dummies(df_applications)
df_app_num.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
from os import X_OK
# Split our preprocessed data into our features and target arrays
X= df_app_num.drop(['IS_SUCCESSFUL'], axis = 'columns').values
y = df_app_num['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# define the model - deep neural net
nn_model = tf.keras.models.Sequential()

number_input_features = len(X_train[0])
number_nodes_1 = 100
number_nodes_2 = 30
number_nodes_3 = 30
number_nodes_output = 1


# add first hidden layer
nn_model.add(
    tf.keras.layers.Dense(units=number_nodes_1, input_dim=number_input_features, activation=tf.keras.layers.LeakyReLU(alpha=0.01))
)

# add second hidden layer
nn_model.add(tf.keras.layers.Dense(units = number_nodes_2, input_dim = number_input_features, activation = "tanh"))

# add third hidden layer
nn_model.add(tf.keras.layers.Dense(units = number_nodes_3, input_dim = number_input_features, activation = "sigmoid"))


# add output layer

nn_model.add((tf.keras.layers.Dense(units = number_nodes_output, input_dim = number_input_features, activation = "sigmoid")))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               10900
#
#  dense_1 (Dense)             (None, 30)                3030
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 1)                 31
#
# ...
# Total params: 14891 (58.17 KB)
# Trainable params: 14891 (58.17 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5770 - accuracy: 0.7141
# Epoch 2/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7285
# Epoch 3/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7317
# Epoch 4/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5483 - accuracy: 0.7315
# Epoch 5/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7315
# Epoch 6/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7311
# Epoch 7/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7314
# Epoch 8/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7352
# Epoch 9/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7341
# Epoch 10/75
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5555 - accuracy: 0.7271 - 752ms/epoch - 3ms/step
# Loss: 0.5555157661437988, Accuracy: 0.7271137237548828

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
